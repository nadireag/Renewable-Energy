# %% [markdown]
# # Clean the Data

# %%
# import dependencies

import pandas as pd

# %%
# read the data 
df = pd.read_csv("db/prod-data.csv")
pd.set_option('display.max_columns', None)
df
# Out:
#                    State    1960    1961    1962    1963    1964    1965  \
# 0                 Alaska    6800    7313    7453    7793    8102    8519
# 1                Alabama  112809  118021  125564  112682  137992  121888
# 2               Arkansas   48104   51144   47637   41897   42732   46425
# 3                Arizona   36181   35083   34533   34861   34271   50095
# 4             California  270161  248178  329046  360333  331757  418518
# 5               Colorado   16914   15464   17144   17410   17865   16369
# 6            Connecticut   17406   17076   15937   16253   16703   15500
# 7   District of Columbia     155     163     166     148     138     120
# 8               Delaware    4982    5101    5134    5356    5510    5577
# 9                Florida   35680   34417   35826   38613   39016   39916
# 10               Georgia   96016   94590   96771  103171  118296  108022
# 11                Hawaii     292     258     214     446    1429    1265
# ...

# %%
# see the df details
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 59 columns):
# State    51 non-null object
# 1960     51 non-null int64
# 1961     51 non-null int64
# 1962     51 non-null int64
# 1963     51 non-null int64
# 1964     51 non-null int64
# 1965     51 non-null int64
# 1966     51 non-null int64
# 1967     51 non-null int64
# 1968     51 non-null int64
# 1969     51 non-null int64
# 1970     51 non-null int64
# 1971     51 non-null int64
# 1972     51 non-null int64
# 1973     51 non-null int64
# 1974     51 non-null int64
# 1975     51 non-null int64
# 1976     51 non-null int64
# 1977     51 non-null int64
# 1978     51 non-null int64
# 1979     51 non-null int64
# 1980     51 non-null int64
# 1981     51 non-null int64
# 1982     51 non-null int64
# 1983     51 non-null int64
# 1984     51 non-null int64
# 1985     51 non-null int64
# 1986     51 non-null int64
# 1987     51 non-null int64
# 1988     51 non-null int64
# ...

# %%
# convert the data change columns to rows so our data is linear

clean_df = df.melt(id_vars=["State"], 
        var_name="Year", 
        value_name="Data")
pd.set_option('display.max_rows', None)
clean_df.head(52)
# Out:
#                    State  Year    Data
# 0                 Alaska  1960    6800
# 1                Alabama  1960  112809
# 2               Arkansas  1960   48104
# 3                Arizona  1960   36181
# 4             California  1960  270161
# 5               Colorado  1960   16914
# 6            Connecticut  1960   17406
# 7   District of Columbia  1960     155
# 8               Delaware  1960    4982
# 9                Florida  1960   35680
# 10               Georgia  1960   96016
# 11                Hawaii  1960     292
# 12                  Iowa  1960   15884
# 13                 Idaho  1960   77688
# 14              Illinois  1960   33020
# 15               Indiana  1960   24556
# 16                Kansas  1960    4123
# 17              Kentucky  1960   50751
# 18             Louisiana  1960   38992
# 19         Massachusetts  1960   53354
# 20              Maryland  1960   38447
# 21                 Maine  1960   59784
# 22              Michigan  1960   59100
# ...

# %%
# save the dataframe as csv
clean_df.to_csv("db/produced_renewable.csv")
